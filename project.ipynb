# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_excel("student_academic_data.xlsx")
df= pd.DataFrame(data)

df.head()
# Out:
#    Student ID First Name Last Name                            Email  Gender  \
# 0        1001      Aarav    Sharma  aarav.sharma1001@university.edu    Male
# 1        1002      Priya     Mehta   priya.mehta1002@university.edu  Female
# 2        1003      Rohan     Verma   rohan.verma1003@university.edu    Male
# 3        1004      Sneha      Iyer    sneha.iyer1004@university.edu  Female
# 4        1005      Kiran     Reddy   kiran.reddy1005@university.edu    Male
#
#                 Department  Attendance (%)  Mid Score  Final Score  \
# 0  Business Administration              45         20           20
# 1         Computer Science              51         32           43
# 2  Business Administration              45         20           20
# 3   Mechanical Engineering              45         27           37
# 4   Mechanical Engineering              45         33           20
#
#    Assignment Score  Quizzes Score  Participation Score  Total Score Grade  \
# ...

# %%
x=df[["Study Hours/Day"]]
y =df["Final Score"]

# Train the Model 

model =LinearRegression()
model.fit(x,y)

predicted_scores = model.predict(x)

# valid regression metrics 

mae = mean_absolute_error(y, predicted_scores)
mse = mean_squared_error(y, predicted_scores)
rsme = np.sqrt(mse)
r2= r2_score(y,predicted_scores)

# Showing the REasult 

print(f"The Mean Absolute Error is {round(mae,2)}")
print(f"The Mean Square Error is {round(mse,2)} ")
print(f"The The Square Root of the mean Error is {round(rsme,2)}")
print(f"The R^2 scor(Model Accuracy) is {round(r2,2)}") # closer to 1 = Better
# Out:
# The Mean Absolute Error is 4.62
# The Mean Square Error is 29.22
# The The Square Root of the mean Error is 5.41
# The R^2 scor(Model Accuracy) is 0.91

# %%
# Histogram
plt.Figure(figsize=(10,6)) #(Width, Height)
plt.hist(df["Final Score"], bins=30, color="skyblue", edgecolor="black")

plt.title("Distribution of final Exam Scores")
plt.xlabel("Final Exam Score")
plt.ylabel("Number of students")
plt.grid(True)
plt.show()

# %%
# "The scores are tightly clustered with low standard deviation."

# %%
# Scatter + Regression Line 

plt.figure(figsize=(10,6))
plt.scatter(x, y, color="blue", label="Actaual Scores")
plt.plot(x, predicted_scores, color="red", label="Predicted Scores (Regression Lines)")
plt.title("Model Prediction VS Actual Score")
plt.xlabel("Study Hours per Day")
plt.ylabel("Final Output")
plt.grid(True)
plt.show()

# %%
new_hours  = 9
predicted_new_score =model.predict([[new_hours]])

print("Predicted final score for new hour is ",predicted_new_score)
# Out:
# Predicted final score for new hour is  [86.89509982]
# c:\Users\sonty\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
